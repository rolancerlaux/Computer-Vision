# %% [markdown]
# ### Initial imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ### Reading Images

# %%
# Load an image using 'imread' specifying the path to image
image = cv2.imread('../Computer_vision/archive/1beatle.jpg')

plt.imshow(image)

# %%
# Let's print each dimension of the image
print('Height of Image:', int(image.shape[0]), 'pixels')
print('Width of Image: ', int(image.shape[1]), 'pixels')
# Out:
# Height of Image: 159 pixels
# Width of Image:  318 pixels

# %% [markdown]
# ### Grayscaling

# %%
# Grayscaling is process by which an image is converted from a full color to shades of grey (black & white)

# %%
# We use cvtColor, to convert to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray_image)

# %% [markdown]
# ### Let's take a closer look at color spaces

# %%
# First thing to remember about OpenCV's RGB is that it's BGR (I know, this is annoying)
# Let's look at the image shape again. The '3L'

# %%
# BGR Values for the first 0,0 pixel
B, G, R = image[10, 50] 

print(B, G, R)
print(image.shape)
# Out:
# 255 255 255
# (159, 318, 3)

# %%
# Let's see what happens when we convert it to grayscale

print(gray_image[10, 50]) 
print(gray_image.shape)
# Out:
# 255
# (159, 318)

# %%
# It's now only 2 dimensions. Each pixel coordinate has only one value (previously 3) with a range of 0 to 255

# %% [markdown]
# ### Another useful color space is HSV

# %%
#H: 0 - 180, S: 0 - 255, V: 0 - 255
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
plt.imshow(hsv_image)

# %% [markdown]
# ### Histograms are a great way to visualize individual color components

# %%
# Let's load another image
image = cv2.imread('../Computer_vision/archive/1chihuahua.jpg')
plt.imshow(image)

# %%
# Making a histogram
histogram = cv2.calcHist([image], [0], None, [256], [0, 256])

# We plot a histogram, ravel() flatens our image array 
plt.hist(image.ravel(), 256, [0, 256]); plt.show()

# Viewing Separate Color Channels
color = ('b', 'g', 'r')

# We now separate the colors and plot each in the Histogram
for i, col in enumerate(color):
    histogram2 = cv2.calcHist([image], [i], None, [256], [0, 256])
    plt.plot(histogram2, color = col)
    plt.xlim([0,256])

# %%
# One more image
image = cv2.imread('../Computer_vision/archive/1abraham.jpg')
plt.imshow(image)

# %%
# Making a histogram
histogram = cv2.calcHist([image], [0], None, [256], [0, 256])

# We plot a histogram, ravel() flatens our image array 
plt.hist(image.ravel(), 256, [0, 256]); plt.show()

# Viewing Separate Color Channels
color = ('b', 'g', 'r')

# We now separate the colors and plot each in the Histogram
for i, col in enumerate(color):
    histogram2 = cv2.calcHist([image], [i], None, [256], [0, 256])
    plt.plot(histogram2, color = col)
    plt.xlim([0,256])

# %% [markdown]
# ### Drawing images and shapes using OpenCV

# %%
# Create a black image
image = np.zeros((512,512,3),np.uint8)
plt.imshow(image)

# %% [markdown]
# ### Let's draw a line over our black square

# %%
# cv2.line(image, starting cordinates, ending cordinates, color, thickness)

# %%
# Draw a diagonal  line of thickness of 5 pixels
cv2.line(image, (0,0), (511, 511), (255,127,0), 5)
plt.imshow(image)

# %% [markdown]
# ### Let's now draw a rectangle

# %%
# cv2.rectangle(image, starting vertex, opposite vertex, color, thickness)

# %%
# Draw a Rectangle in
cv2.rectangle(image, (100,100), (300,250), (127,50,127), -1)
plt.imshow( image)

# %% [markdown]
# ### Let's now draw a circle

# %%
# cv2.cirlce(image, center, radius, color, fill)

# %%
# Draw a circle in
cv2.circle(image, (350,350), 100, (15,75,50), -1)
plt.imshow(image)

# %% [markdown]
# ### And Also Polygons..

# %%
image = np.zeros((512, 512, 3), np.uint8)

# Let's define four points
pts = np.array( [[101, 50], [350, 50], [150, 200], [80, 450]], np.int32)

# Let's now reshape our points in form  required by polylines
pts = pts.reshape((-1,1,2))

cv2.polylines(image, [pts], True, (0,0,255), 3)
plt.imshow(image)

# %% [markdown]
# ### Let's even add text with cv2.putText

# %%
# cv2.putText(image, 'Text to Display', bottom left starting point, Font, Font Size, Color, Thickness)

# FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN
# FONT_HERSHEY_DUPLEX,FONT_HERSHEY_COMPLEX
# FONT_HERSHEY_TRIPLEX, FONT_HERSHEY_COMPLEX_SMALL
# FONT_HERSHEY_SCRIPT_SIMPLEX
# FONT_HERSHEY_SCRIPT_COMPLEX

# %%
# Create a black image
image = np.zeros((512, 512, 3), np.uint8)

# Put the text
cv2.putText(image,"That's all folks", (20, 280), cv2.FONT_HERSHEY_DUPLEX, 2, (100, 170, 0), 2)
plt.imshow(image)
